# %%
# !pip install yfinance
# Out:
# Requirement already satisfied: yfinance in c:\users\ch\documents\python scripts\lib\site-packages (0.2.28)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in c:\users\ch\documents\python scripts\lib\site-packages (from yfinance) (4.11.1)
# Requirement already satisfied: numpy>=1.16.5 in c:\users\ch\documents\python scripts\lib\site-packages (from yfinance) (1.23.5)
# Requirement already satisfied: pandas>=1.3.0 in c:\users\ch\documents\python scripts\lib\site-packages (from yfinance) (1.5.3)
# Requirement already satisfied: appdirs>=1.4.4 in c:\users\ch\documents\python scripts\lib\site-packages (from yfinance) (1.4.4)
# Requirement already satisfied: requests>=2.31 in c:\users\ch\documents\python scripts\lib\site-packages (from yfinance) (2.31.0)
# Requirement already satisfied: multitasking>=0.0.7 in c:\users\ch\documents\python scripts\lib\site-packages (from yfinance) (0.0.11)
# Requirement already satisfied: lxml>=4.9.1 in c:\users\ch\documents\python scripts\lib\site-packages (from yfinance) (4.9.1)
# Requirement already satisfied: frozendict>=2.3.4 in c:\users\ch\documents\python scripts\lib\site-packages (from yfinance) (2.3.8)
# Requirement already satisfied: pytz>=2022.5 in c:\users\ch\documents\python scripts\lib\site-packages (from yfinance) (2022.7)
# Requirement already satisfied: html5lib>=1.1 in c:\users\ch\documents\python scripts\lib\site-packages (from yfinance) (1.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\ch\documents\python scripts\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.3.2.post1)
# Requirement already satisfied: webencodings in c:\users\ch\documents\python scripts\lib\site-packages (from html5lib>=1.1->yfinance) (0.5.1)
# Requirement already satisfied: six>=1.9 in c:\users\ch\documents\python scripts\lib\site-packages (from html5lib>=1.1->yfinance) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\ch\documents\python scripts\lib\site-packages (from pandas>=1.3.0->yfinance) (2.8.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\ch\documents\python scripts\lib\site-packages (from requests>=2.31->yfinance) (2.0.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\ch\documents\python scripts\lib\site-packages (from requests>=2.31->yfinance) (1.26.14)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ch\documents\python scripts\lib\site-packages (from requests>=2.31->yfinance) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ch\documents\python scripts\lib\site-packages (from requests>=2.31->yfinance) (2022.12.7)

# %%
import yfinance as yf

# %%
blackrock= yf.Ticker("BLK")

# %%
blackrock.info
# Out:
# {'address1': '50 Hudson Yards',
#  'city': 'New York',
#  'state': 'NY',
#  'zip': '10001',
#  'country': 'United States',
#  'phone': '212 810 5800',
#  'website': 'https://www.blackrock.com',
#  'industry': 'Asset Management',
#  'industryDisp': 'Asset Management',
#  'sector': 'Financial Services',
#  'sectorDisp': 'Financial Services',
#  'longBusinessSummary': 'BlackRock, Inc. is a publicly owned investment manager. The firm primarily provides its services to institutional, intermediary, and individual investors including corporate, public, union, and industry pension plans, insurance companies, third-party mutual funds, endowments, public institutions, governments, foundations, charities, sovereign wealth funds, corporations, official institutions, and banks. It also provides global risk management and advisory services. The firm manages separate client-focused equity, fixed income, and balanced portfolios. It also launches and manages open-end and closed-end mutual funds, offshore funds, unit trusts, and alternative investment vehicles including structured funds. The firm launches equity, fixed income, balanced, and real estate mutual funds. It also launches equity, fixed income, balanced, currency, commodity, and multi-asset exchange traded funds. The firm also launches and manages hedge funds. It invests in the public equity, fixed income, real estate, currency, commodity, and alternative markets across the globe. The firm primarily invests in growth and value stocks of small-cap, mid-cap, SMID-cap, large-cap, and multi-cap companies. It also invests in dividend-paying equity securities. The firm invests in investment grade municipal securities, government securities including securities issued or guaranteed by a government or a government agency or instrumentality, corporate bonds, and asset-backed and mortgage-backed securities. It employs fundamental and quantitative analysis with a focus on bottom-up and top-down approach to make its investments. The firm employs liquidity, asset allocation, balanced, real estate, and alternative strategies to make its investments. In real estate sector, it seeks to invest in Poland and Germany. The firm benchmarks the performance of its portfolios against various S&P, Russell, Barclays, MSCI, Citigroup, and Merrill Lynch indices. BlackRock, Inc. was founded in 1988 and is based in New York City with additional offices in Boston, Massachusetts; London, United Kingdom; Gurgaon, India; Hong Kong; Greenwich, Connecticut; Princeton, New Jersey; Edinburgh, United Kingdom; Sydney, Australia; Taipei, Taiwan; Singapore; Sao Paulo, Brazil; Philadelphia, Pennsylvania; Washington, District of Columbia; Toronto, Canada; Wilmington, Delaware; and San Francisco, California.',
#  'fullTimeEmployees': 19300,
#  'companyOfficers': [{'maxAge': 1,
#    'name': 'Mr. Laurence Douglas Fink',
#    'age': 70,
#    'title': 'Chairman & CEO',
#    'yearBorn': 1952,
#    'fiscalYear': 2022,
#    'totalPay': 9475555,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Robert Steven Kapito',
#    'age': 66,
#    'title': 'Pres & Director',
#    'yearBorn': 1956,
#    'fiscalYear': 2022,
#    'totalPay': 7133430,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Robert Lawrence Goldstein',
#    'age': 48,
#    'title': 'Sr. MD & COO',
#    'yearBorn': 1974,
#    'fiscalYear': 2022,
#    'totalPay': 3104195,
#    'exercisedValue': 0,
#    'unexercisedValue': 7036193},
#   {'maxAge': 1,
#    'name': 'Mr. J. Richard Kushel',
#    'age': 55,
#    'title': 'Sr. MD & Head of the Portfolio Management Group',
#    'yearBorn': 1967,
#    'fiscalYear': 2022,
#    'totalPay': 2604195,
#    'exercisedValue': 0,
#    'unexercisedValue': 5277096},
#   {'maxAge': 1,
#    'name': 'Mr. Gary Stephen Shedlin',
#    'age': 59,
#    'title': 'Vice Chairman',
#    'yearBorn': 1963,
#    'fiscalYear': 2022,
#    'totalPay': 2214794,
#    'exercisedValue': 0,
#    'unexercisedValue': 5277096},
#   {'maxAge': 1,
#    'name': 'Dr. Bennett W. Golub Ph.D.',
#    'age': 64,
#    'title': 'Co-Founder',
#    'yearBorn': 1958,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Mark  McKenna',
#    'title': 'Founder, MD, Global Head of Event Driven Equity Strategies & Portfolio Mang.',
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Martin  Small',
#    'title': 'Sr. MD, CFO & Global Head of Corp. Strategy',
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Dr. Jeff  Shen Ph.D.',
#    'title': 'MD, Co-CIO & Co-Head of Systematic Active Equity (SAE)',
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Neeraj  Seth',
#    'title': 'MD, Chief Investment Officer & Head of Asian credit \x96 Singapore',
#    'exercisedValue': 0,
#    'unexercisedValue': 0}],
#  'auditRisk': 4,
#  'boardRisk': 7,
#  'compensationRisk': 6,
#  'shareHolderRightsRisk': 1,
#  'overallRisk': 3,
#  'governanceEpochDate': 1693180800,
#  'compensationAsOfEpochDate': 1672444800,
#  'maxAge': 86400,
#  'priceHint': 2,
#  'previousClose': 700.54,
#  'open': 704.2,
#  'dayLow': 701.4,
#  'dayHigh': 706.98,
#  'regularMarketPreviousClose': 700.54,
#  'regularMarketOpen': 704.2,
#  'regularMarketDayLow': 701.4,
#  'regularMarketDayHigh': 706.98,
#  'dividendRate': 20.0,
#  'dividendYield': 0.028499998,
#  'exDividendDate': 1694044800,
#  'payoutRatio': 0.5771,
#  'fiveYearAvgDividendYield': 2.52,
#  'beta': 1.288534,
#  'trailingPE': 20.565823,
#  'forwardPE': 17.367144,
#  'volume': 163176,
#  'regularMarketVolume': 163176,
#  'averageVolume': 553022,
#  'averageVolume10days': 431170,
#  'averageDailyVolume10Day': 431170,
#  'bid': 704.36,
#  'ask': 704.94,
#  'bidSize': 1400,
#  'askSize': 800,
#  'marketCap': 105196666880,
#  'fiftyTwoWeekLow': 503.12,
#  'fiftyTwoWeekHigh': 785.65,
#  'priceToSalesTrailing12Months': 6.061811,
#  'fiftyDayAverage': 703.7418,
#  'twoHundredDayAverage': 695.91876,
#  'trailingAnnualDividendRate': 19.76,
#  'trailingAnnualDividendYield': 0.028206812,
#  'currency': 'USD',
#  'enterpriseValue': 109372465152,
#  'profitMargins': 0.29895002,
#  'floatShares': 139815944,
#  'sharesOutstanding': 149303008,
#  'sharesShort': 2383962,
#  'sharesShortPriorMonth': 2111396,
#  'sharesShortPreviousMonthDate': 1689292800,
#  'dateShortInterest': 1692057600,
#  'sharesPercentSharesOut': 0.016,
#  'heldPercentInsiders': 0.01028,
#  'heldPercentInstitutions': 0.84982,
#  'shortRatio': 4.5,
#  'shortPercentOfFloat': 0.0161,
#  'impliedSharesOutstanding': 149303008,
#  'bookValue': 255.789,
#  'priceToBook': 2.7545555,
#  'lastFiscalYearEnd': 1672444800,
#  'nextFiscalYearEnd': 1703980800,
#  'mostRecentQuarter': 1688083200,
#  'earningsQuarterlyGrowth': 0.268,
#  'netIncomeToCommon': 5187999744,
#  'trailingEps': 34.26,
#  'forwardEps': 40.57,
#  'pegRatio': 1.95,
#  'enterpriseToRevenue': 6.302,
#  'enterpriseToEbitda': 16.749,
#  '52WeekChange': 0.06455338,
#  'SandP52WeekChange': 0.14866495,
#  'lastDividendValue': 5.0,
#  'lastDividendDate': 1686096000,
#  'exchange': 'NYQ',
#  'quoteType': 'EQUITY',
#  'symbol': 'BLK',
#  'underlyingSymbol': 'BLK',
#  'shortName': 'BlackRock, Inc.',
#  'longName': 'BlackRock, Inc.',
#  'firstTradeDateEpochUtc': 938784600,
#  'timeZoneFullName': 'America/New_York',
#  'timeZoneShortName': 'EDT',
#  'uuid': '386ad08c-9fb4-35ee-a9b0-7905b98af57b',
#  'messageBoardId': 'finmb_403413',
#  'gmtOffSetMilliseconds': -14400000,
#  'currentPrice': 704.585,
#  'targetHighPrice': 921.0,
#  'targetLowPrice': 710.0,
#  'targetMeanPrice': 817.38,
#  'targetMedianPrice': 814.0,
#  'recommendationMean': 1.9,
#  'recommendationKey': 'buy',
#  'numberOfAnalystOpinions': 13,
#  'totalCash': 6625999872,
#  'totalCashPerShare': 44.38,
#  'ebitda': 6529999872,
#  'totalDebt': 9717999616,
#  'quickRatio': 1.25,
#  'currentRatio': 1.974,
#  'totalRevenue': 17354000384,
#  'debtToEquity': 24.358,
#  'revenuePerShare': 115.66,
#  'returnOnAssets': 0.03069,
#  'returnOnEquity': 0.13453001,
#  'grossProfits': 8787000000,
#  'freeCashflow': 3884375040,
#  'operatingCashflow': 4323999744,
#  'earningsGrowth': 0.283,
#  'revenueGrowth': -0.014,
#  'grossMargins': 0.48525003,
#  'ebitdaMargins': 0.37627998,
#  'operatingMargins': 0.35167998,
#  'financialCurrency': 'USD',
#  'trailingPegRatio': 2.8014}

# %%
blk_price= blackrock.history(period="7d")
blk_price
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2023-08-24 00:00:00-04:00  678.780029  688.580017  672.969971  673.159973
# 2023-08-25 00:00:00-04:00  676.000000  682.200012  671.260010  675.960022
# 2023-08-28 00:00:00-04:00  681.309998  683.539978  674.630005  679.000000
# 2023-08-29 00:00:00-04:00  678.650024  691.460022  676.549988  691.030029
# 2023-08-30 00:00:00-04:00  691.780029  699.500000  689.809998  695.809998
# 2023-08-31 00:00:00-04:00  697.869995  704.440002  693.799988  700.539978
# 2023-09-01 00:00:00-04:00  704.200012  706.979980  701.400024  704.849976
#
#                            Volume  Dividends  Stock Splits
# Date
# 2023-08-24 00:00:00-04:00  317900        0.0           0.0
# 2023-08-25 00:00:00-04:00  275200        0.0           0.0
# 2023-08-28 00:00:00-04:00  430900        0.0           0.0
# 2023-08-29 00:00:00-04:00  502600        0.0           0.0
# 2023-08-30 00:00:00-04:00  483900        0.0           0.0
# 2023-08-31 00:00:00-04:00  617100        0.0           0.0
# 2023-09-01 00:00:00-04:00  165356        0.0           0.0

# %%
blk_price.to_csv('blackrock.csv')

# %%
# !pip install mplfinance
# Out:
# Requirement already satisfied: mplfinance in c:\users\ch\documents\python scripts\lib\site-packages (0.12.10b0)
# Requirement already satisfied: pandas in c:\users\ch\documents\python scripts\lib\site-packages (from mplfinance) (1.5.3)
# Requirement already satisfied: matplotlib in c:\users\ch\documents\python scripts\lib\site-packages (from mplfinance) (3.7.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\ch\documents\python scripts\lib\site-packages (from matplotlib->mplfinance) (0.11.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\ch\documents\python scripts\lib\site-packages (from matplotlib->mplfinance) (22.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\ch\documents\python scripts\lib\site-packages (from matplotlib->mplfinance) (3.0.9)
# Requirement already satisfied: numpy>=1.20 in c:\users\ch\documents\python scripts\lib\site-packages (from matplotlib->mplfinance) (1.23.5)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\ch\documents\python scripts\lib\site-packages (from matplotlib->mplfinance) (1.4.4)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\ch\documents\python scripts\lib\site-packages (from matplotlib->mplfinance) (2.8.2)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\ch\documents\python scripts\lib\site-packages (from matplotlib->mplfinance) (4.25.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\ch\documents\python scripts\lib\site-packages (from matplotlib->mplfinance) (9.4.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\ch\documents\python scripts\lib\site-packages (from matplotlib->mplfinance) (1.0.5)
# Requirement already satisfied: pytz>=2020.1 in c:\users\ch\documents\python scripts\lib\site-packages (from pandas->mplfinance) (2022.7)
# Requirement already satisfied: six>=1.5 in c:\users\ch\documents\python scripts\lib\site-packages (from python-dateutil>=2.7->matplotlib->mplfinance) (1.16.0)

# %%
import matplotlib.pyplot as plt
from mplfinance.original_flavor import candlestick_ohlc
import matplotlib.dates as mpdates
import pandas as pd

# %%
df= pd.read_csv('blackrock.csv')
df= df[['Date', 'Open', 'High', 'Low', 'Close']]
df['Date']= pd.to_datetime(df['Date'])
df['Date']= df['Date'].map(mpdates.date2num)
fig, ax= plt.subplots()
candlestick_ohlc(ax, df.values, colorup='green', colordown='red', alpha=0.8)
ax.grid(True)
ax.set_xlabel('Date')
ax.set_ylabel('Price')

date_format= mpdates.DateFormatter('%d-%m-%Y')
ax.xaxis.set_major_formatter(date_format)
fig.tight_layout()
plt.show()
